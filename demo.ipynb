# %%
from pymongo.mongo_client import MongoClient

# %%
uri = "mongodb+srv://poonamkulkarni76:Omkar123@cluster0.3wnq1xf.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# %%
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# SSL handshake failed: ac-rut1i6a-shard-00-01.3wnq1xf.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-rut1i6a-shard-00-02.3wnq1xf.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-rut1i6a-shard-00-00.3wnq1xf.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6688c679edd5dd48b9d092a9, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-rut1i6a-shard-00-00.3wnq1xf.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-rut1i6a-shard-00-00.3wnq1xf.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] 
# ...

# %%
# This is my database
mydb=client["mydatabase"]

# %%
# collection of data:
mycol=mydb["myFirstCollection"]

# %%
myFirstRecord={"fname":"Poonam","lname":"Kale","address":"Pune"}

# %%
myFirstRecord
# Out:
# {'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}

# %%
mycol.insert_one(myFirstRecord)
# Out:
# InsertOneResult(ObjectId('6688c697edd5dd48b9d092aa'), acknowledged=True)

# %%
mySecondRecord={"fname":"Omkar","lname":"Kale","address":"Pune"}

# %%
mycol.insert_one(mySecondRecord)
# Out:
# InsertOneResult(ObjectId('6688c8ebedd5dd48b9d092ab'), acknowledged=True)

# %%
multirecords=[{"fname":"Omkar","lname":"Kale","address":"Pune"},
              
              {"fname":"Poonam","lname":"Kale","address":"Pune"},
              {"fname":"Omkar","lname":"Kale","address":"Pune","sal":100000},
              {"f{name":"Poonam","lname":"Kale","address":"Pune","sal":500000},
]

# %%
x=mycol.insert_many(multirecords)

# %%
x.inserted_ids
# Out:
# [ObjectId('6688d21bedd5dd48b9d092ac'),
#  ObjectId('6688d21bedd5dd48b9d092ad'),
#  ObjectId('6688d21bedd5dd48b9d092ae'),
#  ObjectId('6688d21bedd5dd48b9d092af')]

# %%
multirecords=[
    {"_id":1,"fname":"Omkar","lname":"Kale","address":"Pune"},
              
    {"_id":2,"fname":"Poonam","lname":"Kale","address":"Pune"},

    
]

# %%
# method for fetching records:
mycol.find_one()
# Out:
# {'_id': ObjectId('6688c697edd5dd48b9d092aa'),
#  'fname': 'Poonam',
#  'lname': 'Kale',
#  'address': 'Pune'}

# %%
mycol.find()

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('6688c697edd5dd48b9d092aa'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688c8ebedd5dd48b9d092ab'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ac'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ad'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ae'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune', 'sal': 100000}
# {'_id': ObjectId('6688d21bedd5dd48b9d092af'), 'f{name': 'Poonam', 'lname': 'Kale', 'address': 'Pune', 'sal': 500000}
# {'_id': 1, 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': 2, 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}

# %%
for x in mycol.find({"address":"Pune"}):
    print(x)
# Out:
# {'_id': ObjectId('6688c697edd5dd48b9d092aa'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688c8ebedd5dd48b9d092ab'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ac'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ad'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ae'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune', 'sal': 100000}
# {'_id': ObjectId('6688d21bedd5dd48b9d092af'), 'f{name': 'Poonam', 'lname': 'Kale', 'address': 'Pune', 'sal': 500000}
# {'_id': 1, 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': 2, 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}

# %%
for x in mycol.find().sort("fname"):
    print(x)
# Out:
# {'_id': ObjectId('6688d21bedd5dd48b9d092af'), 'f{name': 'Poonam', 'lname': 'Kale', 'address': 'Pune', 'sal': 500000}
# {'_id': ObjectId('6688c8ebedd5dd48b9d092ab'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ac'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ae'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune', 'sal': 100000}
# {'_id': 1, 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688c697edd5dd48b9d092aa'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ad'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': 2, 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}

# %%
mycol.delete_one({"fname":"Poonam"})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000016'), 'opTime': {'ts': Timestamp(1720247598, 1), 't': 22}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1720247598, 1), 'signature': {'hash': b'_\x8c\xa0\xc5\x1ejS\x0fT\xa32\x1a\xf3\xb0vj\xbb\x17\x1c\xbe', 'keyId': 7361875074091057157}}, 'operationTime': Timestamp(1720247598, 1)}, acknowledged=True)

# %%
for x in mycol.find().sort("fname"):
    print(x)
# Out:
# {'_id': ObjectId('6688d21bedd5dd48b9d092af'), 'f{name': 'Poonam', 'lname': 'Kale', 'address': 'Pune', 'sal': 500000}
# {'_id': ObjectId('6688c8ebedd5dd48b9d092ab'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ac'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ae'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune', 'sal': 100000}
# {'_id': 1, 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ad'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': 2, 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}

# %%
for x in mycol.find().sort("fname",-1):
    print(x)
# Out:
# {'_id': ObjectId('6688d21bedd5dd48b9d092ad'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': 2, 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688c8ebedd5dd48b9d092ab'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ac'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ae'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune', 'sal': 100000}
# {'_id': 1, 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092af'), 'f{name': 'Poonam', 'lname': 'Kale', 'address': 'Pune', 'sal': 500000}

# %%
for x in mycol.find().limit(4):
    print(x)
# Out:
# {'_id': ObjectId('6688c8ebedd5dd48b9d092ab'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ac'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ad'), 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ae'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune', 'sal': 100000}

# %%
myquery={"fname":"Poonam"}
newvalue={"$set":{"fname":"Omiii"}}

# %%
mycol.update_one(myquery,newvalue)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000016'), 'opTime': {'ts': Timestamp(1720248276, 2), 't': 22}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1720248276, 2), 'signature': {'hash': b'\xdd\x1e9\x86OV\x90\xc0\x0f{\xdb\x98f\x153:*zC\xd2', 'keyId': 7361875074091057157}}, 'operationTime': Timestamp(1720248276, 2), 'updatedExisting': True}, acknowledged=True)

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('6688c8ebedd5dd48b9d092ab'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ac'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ad'), 'fname': 'Omiii', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ae'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune', 'sal': 100000}
# {'_id': ObjectId('6688d21bedd5dd48b9d092af'), 'f{name': 'Poonam', 'lname': 'Kale', 'address': 'Pune', 'sal': 500000}
# {'_id': 1, 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': 2, 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}

# %%
mycol.update_one({"lname":"Kale"},{"$set":{"lname":"bhargav"}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000016'), 'opTime': {'ts': Timestamp(1720248415, 11), 't': 22}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1720248415, 11), 'signature': {'hash': b'E~\x83\x96\xc8\xc4\x9a\xf8\xb2C\xe3\xab\xc9\xc9\x1d\xc6\x9d\x8d-8', 'keyId': 7361875074091057157}}, 'operationTime': Timestamp(1720248415, 11), 'updatedExisting': True}, acknowledged=True)

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('6688c8ebedd5dd48b9d092ab'), 'fname': 'Omkar', 'lname': 'bhargav', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ac'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ad'), 'fname': 'Omiii', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': ObjectId('6688d21bedd5dd48b9d092ae'), 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune', 'sal': 100000}
# {'_id': ObjectId('6688d21bedd5dd48b9d092af'), 'f{name': 'Poonam', 'lname': 'Kale', 'address': 'Pune', 'sal': 500000}
# {'_id': 1, 'fname': 'Omkar', 'lname': 'Kale', 'address': 'Pune'}
# {'_id': 2, 'fname': 'Poonam', 'lname': 'Kale', 'address': 'Pune'}

# %%
for x in mycol.find({"sal":{"$gt":100000}}):
    print(x)
# Out:
# {'_id': ObjectId('6688d21bedd5dd48b9d092af'), 'f{name': 'Poonam', 'lname': 'Kale', 'address': 'Pune', 'sal': 500000}

# %%
mycol.delete_many({})
# Out:
# DeleteResult({'n': 7, 'electionId': ObjectId('7fffffff0000000000000016'), 'opTime': {'ts': Timestamp(1720249156, 1), 't': 22}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1720249156, 7), 'signature': {'hash': b'\x98\x87\xb8\xaeQKpt\x7f\x83\x01\x93\xec\xf9\xaf5\xb4\x99\xf0t', 'keyId': 7361875074091057157}}, 'operationTime': Timestamp(1720249156, 1)}, acknowledged=True)

# %%
for x in mycol.find():
    print(x)

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv(r"c:\Users\HP\Downloads\glass.csv")

# %%
df.head()
# Out:
#    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00  1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00  1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00  1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00  1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26  1

# %%
#i have to convert it into list of records
#list of dict
[
    {},
    {},
    {},
        
    {}
]
# Out:
# [{}, {}, {}, {}]

# %%
len(df.columns)
# Out:
# 10

# %%
#this is my database
mydb=client["mydatabase"]

# %%
mycol2=mydb["glass.csv"]

# %%
df.T.to_json()
# Out:
# '{"0":{"1.52101":1.51761,"13.64":13.89,"4.49":3.6,"1.10":1.36,"71.78":72.73,"0.06":0.48,"8.75":7.83,"0.00":0.0,"0.00.1":0.0,"1":1.0},"1":{"1.52101":1.51618,"13.64":13.53,"4.49":3.55,"1.10":1.54,"71.78":72.99,"0.06":0.39,"8.75":7.78,"0.00":0.0,"0.00.1":0.0,"1":1.0},"2":{"1.52101":1.51766,"13.64":13.21,"4.49":3.69,"1.10":1.29,"71.78":72.61,"0.06":0.57,"8.75":8.22,"0.00":0.0,"0.00.1":0.0,"1":1.0},"3":{"1.52101":1.51742,"13.64":13.27,"4.49":3.62,"1.10":1.24,"71.78":73.08,"0.06":0.55,"8.75":8.07,"0.00":0.0,"0.00.1":0.0,"1":1.0},"4":{"1.52101":1.51596,"13.64":12.79,"4.49":3.61,"1.10":1.62,"71.78":72.97,"0.06":0.64,"8.75":8.07,"0.00":0.0,"0.00.1":0.26,"1":1.0},"5":{"1.52101":1.51743,"13.64":13.3,"4.49":3.6,"1.10":1.14,"71.78":73.09,"0.06":0.58,"8.75":8.17,"0.00":0.0,"0.00.1":0.0,"1":1.0},"6":{"1.52101":1.51756,"13.64":13.15,"4.49":3.61,"1.10":1.05,"71.78":73.24,"0.06":0.57,"8.75":8.24,"0.00":0.0,"0.00.1":0.0,"1":1.0},"7":{"1.52101":1.51918,"13.64":14.04,"4.49":3.58,"1.10":1.37,"71.78":72.08
# ...

# %%
import json
json.loads(df.T.to_json())
# Out:
# {'0': {'1.52101': 1.51761,
#   '13.64': 13.89,
#   '4.49': 3.6,
#   '1.10': 1.36,
#   '71.78': 72.73,
#   '0.06': 0.48,
#   '8.75': 7.83,
#   '0.00': 0.0,
#   '0.00.1': 0.0,
#   '1': 1.0},
#  '1': {'1.52101': 1.51618,
#   '13.64': 13.53,
#   '4.49': 3.55,
#   '1.10': 1.54,
#   '71.78': 72.99,
#   '0.06': 0.39,
#   '8.75': 7.78,
#   '0.00': 0.0,
#   '0.00.1': 0.0,
#   '1': 1.0},
#  '2': {'1.52101': 1.51766,
#   '13.64': 13.21,
#   '4.49': 3.69,
#   '1.10': 1.29,
#   '71.78': 72.61,
#   '0.06': 0.57,
#   '8.75': 8.22,
#   '0.00': 0.0,
#   '0.00.1': 0.0,
#   '1': 1.0},
#  '3': {'1.52101': 1.51742,
#   '13.64': 13.27,
#   '4.49': 3.62,
#   '1.10': 1.24,
#   '71.78': 73.08,
#   '0.06': 0.55,
#   '8.75': 8.07,
#   '0.00': 0.0,
#   '0.00.1': 0.0,
#   '1': 1.0},
#  '4': {'1.52101': 1.51596,
#   '13.64': 12.79,
#   '4.49': 3.61,
#   '1.10': 1.62,
#   '71.78': 72.97,
#   '0.06': 0.64,
#   '8.75': 8.07,
#   '0.00': 0.0,
#   '0.00.1': 0.26,
#   '1': 1.0},
#  '5': {'1.52101': 1.51743,
# ...

# %%
#list of records
mycsvfile=list(json.loads(df.T.to_json()).values())

# %%
mycol2.insert_many(mycsvfile)
# Out:
# InsertManyResult([ObjectId('6688f2dfedd5dd48b9d092b0'), ObjectId('6688f2dfedd5dd48b9d092b1'), ObjectId('6688f2dfedd5dd48b9d092b2'), ObjectId('6688f2dfedd5dd48b9d092b3'), ObjectId('6688f2dfedd5dd48b9d092b4'), ObjectId('6688f2dfedd5dd48b9d092b5'), ObjectId('6688f2dfedd5dd48b9d092b6'), ObjectId('6688f2dfedd5dd48b9d092b7'), ObjectId('6688f2dfedd5dd48b9d092b8'), ObjectId('6688f2dfedd5dd48b9d092b9'), ObjectId('6688f2dfedd5dd48b9d092ba'), ObjectId('6688f2dfedd5dd48b9d092bb'), ObjectId('6688f2dfedd5dd48b9d092bc'), ObjectId('6688f2dfedd5dd48b9d092bd'), ObjectId('6688f2dfedd5dd48b9d092be'), ObjectId('6688f2dfedd5dd48b9d092bf'), ObjectId('6688f2dfedd5dd48b9d092c0'), ObjectId('6688f2dfedd5dd48b9d092c1'), ObjectId('6688f2dfedd5dd48b9d092c2'), ObjectId('6688f2dfedd5dd48b9d092c3'), ObjectId('6688f2dfedd5dd48b9d092c4'), ObjectId('6688f2dfedd5dd48b9d092c5'), ObjectId('6688f2dfedd5dd48b9d092c6'), ObjectId('6688f2dfedd5dd48b9d092c7'), ObjectId('6688f2dfedd5dd48b9d092c8'), ObjectId('6688f2dfedd5dd48b9d0
# ...
